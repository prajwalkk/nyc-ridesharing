# %%
import pandas as pd
from datetime import datetime, timedelta
import numpy as np

# %%
# dateparse = lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
df = pd.read_pickle(r"data\final_input_data.pkl")

# %%
df[df.tpep_pickup_datetime == df.tpep_dropoff_datetime]
# Out:
#         tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1        2016-01-01 00:00:00   2016-01-01 00:00:00                2
# 2        2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 3        2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 45343    2016-01-01 00:40:57   2016-01-01 00:40:57                1
# 185089   2016-01-01 12:51:01   2016-01-01 12:51:01                1
# ...                      ...                   ...              ...
# 8908337  2016-01-10 00:00:00   2016-01-10 00:00:00                1
# 8908338  2016-01-10 00:00:00   2016-01-10 00:00:00                1
# 8908339  2016-01-10 00:00:00   2016-01-10 00:00:00                1
# 8912773  2016-01-10 00:24:56   2016-01-10 00:24:56                1
# 8982974  2016-01-10 13:43:02   2016-01-10 13:43:02                1
#
#          trip_distance  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 1                 1.10          -73.9904          40.7347           -73.9818
# 2                10.54          -73.9846          40.6796           -73.9503
# 3                 4.75          -73.9935          40.7190           -73.9622
# 45343             2.10          -73.9350          40.8471           -73.9350
# 185089            0.10          -73.9738          40.7450           -73.9738
# ...                ...               ...              ...                ...
# 8908337           1.93          -73.9860          40.7228           -73.9821
# 8908338           8.16          -73.8730          40.7742           -73.9775
# 8908339           5.70          -74.0111          40.7112           -73.8150
# 8912773          10.86          -73.9735          40.7922           -73.8698
# 8982974           0.11          -73.7902          40.6469           -73.7881
#
#          dropoff_latitude
# 1                 40.7324
# 2                 40.7889
# 3                 40.6573
# 45343             40.8471
# 185089            40.7450
# ...                   ...
# 8908337           40.7432
# 8908338           40.7526
# 8908339           40.7026
# 8912773           40.8973
# 8982974           40.6453
#
# [213 rows x 8 columns]
